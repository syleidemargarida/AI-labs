# %%
text="""I am mozambican woman,
I like less spice food,
 when I finish my degree I will start my master in other country,
 My domain is cybersecurity and cloud computing,
 I am marwadi student."""

# %%
#import basic libraries
import nltk
import networkx as nx
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import string

# %%
#download requirements
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def textrank_keyword(text, topn=5,window_size=4):
  word=word_tokenize(text.lower())
  stop_words=set(stop.words('english'))
  words=[w for w in words if w not in stop_words and w not in string.punctuation]
  graph=nx.graph()

  for i,word in enumerate(words):
    for j in range(i+1,window_size+1):
      if(j<len(words)):
        graph.add_edge(word,words[j])

        scores=nx.pagerank(garph)
        ranked_words=sorted(scores.items(),key=lambda x:x[1],reverse=True)
        keywords=[word for word, score in ranked_words[:topn]]
        return keywords

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True
