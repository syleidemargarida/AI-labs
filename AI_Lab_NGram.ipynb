# %%
#Training corpus
corpus = """
I like machine learning
I like deep learning
I enjoy machine learning
I enjoy data science
Machine learning is interesting
Deep learning is powerful
"""

# %%
import nltk
from nltk.util import ngrams
from collections import defaultdict, Counter
import random

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
tokens = nltk.word_tokenize(corpus.lower())

# %%
#build ngram model
n=2
bigrams = list(ngrams(tokens,n))
print(bigrams)
# Out:
# [('i', 'like'), ('like', 'machine'), ('machine', 'learning'), ('learning', 'i'), ('i', 'like'), ('like', 'deep'), ('deep', 'learning'), ('learning', 'i'), ('i', 'enjoy'), ('enjoy', 'machine'), ('machine', 'learning'), ('learning', 'i'), ('i', 'enjoy'), ('enjoy', 'data'), ('data', 'science'), ('science', 'machine'), ('machine', 'learning'), ('learning', 'is'), ('is', 'interesting'), ('interesting', 'deep'), ('deep', 'learning'), ('learning', 'is'), ('is', 'powerful')]

# %%
n=3
trigrams = list(ngrams(tokens,n))
print(trigrams)
# Out:
# [('i', 'like', 'machine'), ('like', 'machine', 'learning'), ('machine', 'learning', 'i'), ('learning', 'i', 'like'), ('i', 'like', 'deep'), ('like', 'deep', 'learning'), ('deep', 'learning', 'i'), ('learning', 'i', 'enjoy'), ('i', 'enjoy', 'machine'), ('enjoy', 'machine', 'learning'), ('machine', 'learning', 'i'), ('learning', 'i', 'enjoy'), ('i', 'enjoy', 'data'), ('enjoy', 'data', 'science'), ('data', 'science', 'machine'), ('science', 'machine', 'learning'), ('machine', 'learning', 'is'), ('learning', 'is', 'interesting'), ('is', 'interesting', 'deep'), ('interesting', 'deep', 'learning'), ('deep', 'learning', 'is'), ('learning', 'is', 'powerful')]

# %%
#create the probability model
model=defaultdict(Counter)
for w1,w2 in bigrams:
  model[w1][w2]+=1
model
# Out:
# defaultdict(collections.Counter,
#             {'i': Counter({'like': 2, 'enjoy': 2}),
#              'like': Counter({'machine': 1, 'deep': 1}),
#              'machine': Counter({'learning': 3}),
#              'learning': Counter({'i': 3, 'is': 2}),
#              'deep': Counter({'learning': 2}),
#              'enjoy': Counter({'machine': 1, 'data': 1}),
#              'data': Counter({'science': 1}),
#              'science': Counter({'machine': 1}),
#              'is': Counter({'interesting': 1, 'powerful': 1}),
#              'interesting': Counter({'deep': 1})})

# %%
#function to predict the next word
def predict_next_word(word):
  word=word.lower()
  if word in model:
    next_words=model[word]
    prediction=max(next_words,key=next_words.get)
    return prediction

  else:
    return "No prediction is done"

# %%
predict_next_word("I")
# Out:
# 'like'
